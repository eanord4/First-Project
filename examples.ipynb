# %%
# Dependencies and Setup
# import matplotlib.pyplot as plt

# import pandas as pd
# import time
# import datetime
# from sodapy import Socrata
# import numpy as np
# import requests
# from pandas.io.json import json_normalize
# from api_keys import crime_key
# import http.client

# import sys

# Import Classes
from classes.weather import Weather
from classes.crime import Crime

# %%
# Get the json version of crimes commited in a date range
obj_crime = Crime()
json_crime = obj_crime.get_json_crime("2020-01-01T01:30:00", "2020-01-01T02:00:00")

# json_crime

# %%
# Get the dataframe version of the given json file
df_crime = obj_crime.get_df_crime(json_crime)
df_crime
# Out:
#         Reported Timestamp Incident Number                     Crime Type  \
# 0  2020-01-01T01:37:00.000       202010385            DISTURBANCE - OTHER
# 1  2020-01-01T01:37:00.000       202010389  AGG ASSAULT FAM/DATE VIOLENCE
# 2  2020-01-01T01:45:00.000       202010408                            DWI
# 3  2020-01-01T01:49:00.000       202010416   POSS CONTROLLED SUB/NARCOTIC
#
#   Highest Offense Code Family Violence            Occurred Date  \
# 0                 3401               N  2020-01-01T00:00:00.000
# 1                  402               Y  2020-01-01T00:00:00.000
# 2                 2100               N  2020-01-01T00:00:00.000
# 3                 1800               N  2020-01-01T00:00:00.000
#
#                   Location Type Zip Code UCR Category Category Description
# 0  STREETS / HWY / ROAD / ALLEY    78701          NaN                  NaN
# 1              RESIDENCE / HOME    78723          13A   Aggravated Assault
# 2  STREETS / HWY / ROAD / ALLEY    78758          NaN                  NaN
# 3  STREETS / HWY / ROAD / ALLEY    78753          NaN                  NaN

# %%
# Get the json version of the weather given lat, long, epoch
obj_weather = Weather()
json_weather = obj_weather.get_json_weather("30.3103","97.7622","1578760316")
# json_weather

# %%
# Get the dataframe version of the given json file
df_weather = obj_weather.get_df_weather(json_weather)
df_weather
# Out:
#           Date  Apparent Temperature  Cloud Cover  Dew Point  Humidity  \
# 0   1578758400                 -3.67         0.37     -17.43      0.33
# 1   1578762000                 -3.47         0.41     -15.73      0.37
# 2   1578765600                 -3.41         0.49     -14.81      0.39
# 3   1578769200                 -5.42         0.66     -16.16      0.39
# 4   1578772800                 -6.68         0.87     -16.89      0.39
# 5   1578776400                 -6.89         0.99     -17.27      0.39
# 6   1578780000                 -7.54         0.94     -17.82      0.39
# 7   1578783600                -10.40         0.80     -18.27      0.42
# 8   1578787200                 -9.70         0.72     -17.83      0.42
# 9   1578790800                 -2.67         0.79     -13.47      0.38
# 10  1578794400                  2.40         0.92     -11.59      0.36
# 11  1578798000                  7.59         0.99      -9.94      0.33
# 12  1578801600                 12.30         0.98      -8.69      0.29
# 13  1578805200                 17.79         0.93      -8.28      0.23
# 14  1578808800                 22.69         0.82      -8.65      0.19
# 15  1578812400                 25.42         0.57      -7.42      0.18
# 16  1578816000                 25.96         0.24      -4.60      0.21
# 17  1578819600                 19.16         0.00      -0.85      0.31
# 18  1578823200                 15.07         0.00      -2.71      0.33
# 19  1578826800                  9.14         0.00      -5.95      0.35
# 20  1578830400                  5.13         0.01      -8.75      0.35
# 21  1578834000                  4.89         0.12      -8.85      0.35
# 22  1578837600                  2.52         0.27     -10.30      0.35
# 23  1578841200                  1.01         0.36     -10.86      0.36
#
#             Description  Precipitation Intensity  Precipitation Probability  \
# 0   partly-cloudy-night                   0.0000                       0.00
# 1   partly-cloudy-night                   0.0000                       0.00
# 2   partly-cloudy-night                   0.0000                       0.00
# 3   partly-cloudy-night                   0.0000                       0.00
# 4   partly-cloudy-night                   0.0000                       0.00
# 5                cloudy                   0.0000                       0.00
# 6                cloudy                   0.0000                       0.00
# 7   partly-cloudy-night                   0.0000                       0.00
# 8   partly-cloudy-night                   0.0000                       0.00
# 9     partly-cloudy-day                   0.0000                       0.00
# 10               cloudy                   0.0000                       0.00
# 11               cloudy                   0.0000                       0.00
# 12               cloudy                   0.0000                       0.00
# 13               cloudy                   0.0000                       0.00
# 14    partly-cloudy-day                   0.0000                       0.00
# 15    partly-cloudy-day                   0.0000                       0.00
# 16            clear-day                   0.0000                       0.00
# 17            clear-day                   0.0000                       0.00
# 18            clear-day                   0.0000                       0.00
# 19          clear-night                   0.0000                       0.00
# 20          clear-night                   0.0003                       0.03
# 21          clear-night                   0.0003                       0.02
# 22          clear-night                   0.0002                       0.02
# 23  partly-cloudy-night                   0.0000                       0.00
#
#     Preassure        Summary  Temperature  UV Index  Visibility  Wind Bearing  \
# 0      1031.6  Partly Cloudy         5.28         0          10           244
# 1      1031.9  Partly Cloudy         5.19         0          10           233
# 2      1032.1  Partly Cloudy         5.01         0          10           228
# 3      1032.5  Mostly Cloudy         3.50         0          10           219
# 4      1033.0  Mostly Cloudy         2.31         0          10           225
# 5      1033.7       Overcast         2.08         0          10           224
# 6      1034.7       Overcast         1.57         0          10           227
# 7      1035.7  Mostly Cloudy        -0.79         0          10           226
# 8      1036.1  Mostly Cloudy        -0.18         0          10           238
# 9      1031.8  Mostly Cloudy         6.87         0          10           210
# 10     1030.3       Overcast        10.25         1          10           311
# 11     1028.1       Overcast        14.15         2          10           265
# 12     1024.9       Overcast        18.58         3          10           264
# 13     1020.6       Overcast        23.92         3          10           261
# 14     1017.0  Mostly Cloudy        28.73         4          10           272
# 15     1014.9  Partly Cloudy        31.01         3          10           317
# 16     1013.7          Clear        31.24         2          10           203
# 17     1013.4          Clear        25.35         1          10           249
# 18     1014.7          Clear        22.05         0          10           257
# 19     1017.1          Clear        17.37         0          10           228
# 20     1019.4          Clear        13.73         0          10           223
# 21     1020.2          Clear        13.71         0          10           241
# 22     1022.1          Clear        12.00         0          10           216
# 23     1023.5  Partly Cloudy        10.94         0          10           214
#
#     Wind Speed
# 0         4.55
# 1         4.35
# 2         4.19
# 3         4.35
# 4         4.27
# 5         4.24
# 6         4.27
# 7         4.35
# 8         4.35
# 9         5.17
# 10        4.36
# 11        3.91
# 12        4.20
# 13        4.81
# 14        5.60
# 15        5.56
# 16        5.24
# 17        5.09
# 18        5.31
# 19        5.67
# 20        5.40
# 21        5.59
# 22        5.90
# 23        6.13
